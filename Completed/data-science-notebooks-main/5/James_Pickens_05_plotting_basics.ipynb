# %% [markdown]
# <a href="https://colab.research.google.com/github/jrpickens/data-science-notebooks/blob/main/5/James_Pickens_05_plotting_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# James Pickens

# %% [markdown]
# # 📈 05 - Plotting Basics
#
# Visualization is a core part of data science.
# In this notebook you will learn:
# - Setting up Matplotlib for inline plotting
# - Creating simple line, scatter, and bar plots
# - Customizing titles, labels, and legends
# - Why visuals matter in data storytelling

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label="sin(x)")
plt.title("Line Plot Example")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Plot `cos(x)` on the same graph with a different color and label.

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)

plt.plot(x, z, label="cos(x)")
plt.plot(x, y, label="sin(x)")
plt.title("Line Plot Example")
plt.xlabel("x")
plt.ylabel("cos(x) and sin(x)")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 300 * np.random.rand(50)
colors = np.random.rand(50)

plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Generate two sets of random points and plot them in different colors on the same scatter plot.

# %%
x = np.random.rand(50)
y = np.random.rand(50)

x1 = np.random.rand(50)
y1 = np.random.rand(50)

plt.scatter(x, y, c="red", alpha=0.6)
plt.scatter(x1, y1, c="blue", alpha=0.6)
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## 4. Bar Plot

# %%
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

plt.bar(categories, values)
plt.title("Bar Plot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Create your own bar chart with at least 4 categories (e.g., favorite foods, courses, or hobbies).

# %%
cat = ["7 days to Die","Celeste", "GTFO", "Terraria","PEAK",  "Rocket League"]
hours = [561, 91.1, 42, 618.5, 91.5, 1552]

plt.bar(cat, hours)
plt.title("Hours Spent Playing Games")
plt.xlabel("Games")
plt.ylabel("Hours")
# Out:
# Text(0, 0.5, 'Hours')

# %% [markdown]
# ## 5. Customizing Plots

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="sin(x)", linestyle="--", color="blue")
plt.plot(x, y2, label="cos(x)", linestyle=":", color="red")
plt.title("Customized Line Plot")
plt.xlabel("x (radians)")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Customize your own plot with labels, legend, and grid lines.

# %%
Champions = ["Gnar", "Kha'Zix", "Yuumi", "Vel'koz", "Zac", "Illaoi"]
Mastery_score = [618499, 478643, 166739, 147955, 108850, 90686]

plt.figure(figsize=(10, 6))
plt.bar(Champions, Mastery_score, color=['#ff7f0e', '#1f77b4',  '#d62728', '#9467bd','#2ca02c', '#8c564b'])
plt.title("Champion Mastery Scores", fontsize = 16, fontweight = 'bold')
plt.xlabel("Champion")
plt.ylabel("Mastery Score")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ---
# ### Summary
# - `%matplotlib inline` makes plots display inside the notebook.
# - Line, scatter, and bar plots are the most common basics.
# - Titles, labels, legends, and grids improve readability.
# - Visuals tell stories about data more effectively than raw numbers.
