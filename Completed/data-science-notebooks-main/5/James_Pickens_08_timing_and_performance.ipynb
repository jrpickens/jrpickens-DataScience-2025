# %% [markdown]
# <a href="https://colab.research.google.com/github/jrpickens/data-science-notebooks/blob/main/5/James_Pickens_08_timing_and_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# James Pickens

# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 8.32 ms, sys: 247 μs, total: 8.56 ms
# Wall time: 8.91 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %%
import random
nums = [random.random() for _ in range(1_000_000)]
# %time nums.sort()
# Out:
# CPU times: user 419 ms, sys: 2.06 ms, total: 421 ms
# Wall time: 422 ms

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]
# Out:
# 59.3 µs ± 4.48 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
# %timeit [i for i in range(1000)]
# Out:
# 28.1 µs ± 641 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def forloop():
  result = []
  for i in range(1000):
      result.append(i)
  return result

# %timeit forloop()
# Out:
# 34.2 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# CPU times: user 251 ms, sys: 0 ns, total: 251 ms
# Wall time: 267 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%time
result = []
for i in range(1000):
    square = i ** 2
    result.append(square)

total = sum(result)
# Out:
# CPU times: user 269 µs, sys: 0 ns, total: 269 µs
# Wall time: 272 µs

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 167 ms ± 39.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.08 ms ± 122 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
# %%timeit
numbers = list(range(1_000_000))
squared = [n**2 for n in numbers]
# Out:
# 253 ms ± 83.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
import numpy as np

numbers = np.arange(1_000_000)
squared = numbers**2
# Out:
# 2.46 ms ± 251 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
